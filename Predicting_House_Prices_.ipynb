# %% [markdown]
# # Importing Libraries and Loading Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load the Dataset

# %%
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()

# %%
type(housing)
# Out:
# sklearn.utils._bunch.Bunch

# %% [markdown]
# Checking Type of dataset

# %%
housing
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]], shape=(20640, 8)),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894], shape=(20640,)),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
# ...

# %% [markdown]
# Checking information about a value of the key

# %%
print(housing.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 20640
#
# :Number of Attributes: 8 numeric, predictive attributes and the target
#
# :Attribute Information:
#     - MedInc        median income in block group
#     - HouseAge      median house age in block group
#     - AveRooms      average number of rooms per household
#     - AveBedrms     average number of bedrooms per household
#     - Population    block group population
#     - AveOccup      average number of household members
#     - Latitude      block group latitude
#     - Longitude     block group longitude
#
# :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# ...

# %% [markdown]
# Getting Predictive attributes of the dataset

# %%
print(housing.feature_names)
# Out:
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']

# %% [markdown]
# Getting target values from the dataset

# %%
print(housing.target)
# Out:
# [4.526 3.585 3.521 ... 0.923 0.847 0.894]

# %% [markdown]
# Creating DataFrame

# %%
dataset = pd.DataFrame(data=housing.data,columns=housing.feature_names)
dataset
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %% [markdown]
# Adding a new column to the dataframe

# %%
dataset['price']=housing.target
dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %% [markdown]
# Get summary of dataframe

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
#  8   price       20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %% [markdown]
# Genetating Descriptive Statistics

# %%
dataset.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude         price
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %% [markdown]
# Check for missing values

# %%
dataset.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# price         0
# dtype: int64

# %% [markdown]
# As there no missing values , missing column/rows so we will do EDA

# %% [markdown]
# Exploratory  Data Analysis

# %%
dataset.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# price       0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude     price
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# ...

# %% [markdown]
# From Correlation Martix we can see :-
# AveBedrms and AveRooms are same
# Longitude and Latitude are same
# Both have very high correlation values approx 1 and -1 .

# %% [markdown]
# i will delete avgrooms and latitude

# %%
dataset = dataset.drop(['AveBedrms', 'Longitude'], axis=1)

# %%
dataset.corr()
# Out:
#               MedInc  HouseAge  AveRooms  Population  AveOccup  Latitude  \
# MedInc      1.000000 -0.119034  0.326895    0.004834  0.018766 -0.079809
# HouseAge   -0.119034  1.000000 -0.153277   -0.296244  0.013191  0.011173
# AveRooms    0.326895 -0.153277  1.000000   -0.072213 -0.004852  0.106389
# Population  0.004834 -0.296244 -0.072213    1.000000  0.069863 -0.108785
# AveOccup    0.018766  0.013191 -0.004852    0.069863  1.000000  0.002366
# Latitude   -0.079809  0.011173  0.106389   -0.108785  0.002366  1.000000
# price       0.688075  0.105623  0.151948   -0.024650 -0.023737 -0.144160
#
#                price
# MedInc      0.688075
# HouseAge    0.105623
# AveRooms    0.151948
# Population -0.024650
# AveOccup   -0.023737
# Latitude   -0.144160
# price       1.000000

# %% [markdown]
# Visualizing Correlation

# %%
sns.pairplot(dataset)

# %% [markdown]
# **Box plot :- To detect the outliers in a given dataset**

# %%
fig,ax = plt.subplots(figsize=(8,8))
sns.boxplot(data=dataset,ax=ax)
plt.savefig('boxplot.jpg')

# %% [markdown]
# **Population**:- very huge Range of numbers(outerliers).
# Machine will treating Population as priority basis

# %% [markdown]
# **Avoiding Bias**
# Normalization of all the feature value

# %%
# MIn-Max Scaling
from sklearn.preprocessing import MinMaxScaler
scaler =MinMaxScaler()
normalized_data = scaler.fit_transform(dataset)

# %% [markdown]
# Splitting the Data

# %%
features = dataset.iloc[:,:-1]
target = dataset.iloc[:,-1]

from sklearn.model_selection import train_test_split
#  Assuming 'features' is your feature matrix and 'target' is your target varible
x_train,x_test,y_train,y_test =train_test_split(features,target,test_size=0.3,random_state=42)

# %% [markdown]
# Normalization of given data points

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_norm = scaler.fit_transform(x_train)
x_test_norm = scaler.transform(x_test)

# %% [markdown]
# Consistent scaling between the training and test sets is crucial for the model to make accurate predictions on new, unseen data. It ensures that the scaling characteristics learned from the training set are applied uniformly to the test set.

# %%
fig,ax = plt.subplots(figsize=(8,8))
sns.boxplot(data=x_train_norm,ax=ax)
plt.savefig('boxplot_train.jpg')

# %%
fig,ax = plt.subplots(figsize=(8,8))
sns.boxplot(data=x_test_norm,ax=ax)
plt.savefig('boxplot_test.jpg')

# %% [markdown]
# Model Training

# %%
import pickle 
with open('scaler.pkl','wb') as f:
    pickle.dump(scaler,f)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
# Initialize the Linear Regression model
regression = LinearRegression()

# %%
# Fit the model to the scaled training data
regression.fit(x_train_norm,y_train)
# Out:
# LinearRegression()

# %%
# Retrieve the slop (m) values
slope_values = regression.coef_

# Retrieve the y-intercept (c) value
intercept_value = regression.intercept_

# %% [markdown]
# So we calucalted the y=mx+c
# m-> slope_values
# c-> intercept_value
# we will 6 intercept values and 1 intercept

# %% [markdown]
# y =mx1+mx2+mx3+mx4+mx5+mx6+c

# %%
print(intercept_value)
# Out:
# 2.069239608942414

# %%
print(slope_values)
# Out:
# [ 0.83151851  0.2221226  -0.04574944  0.02435654 -0.04987447 -0.09353637]

# %% [markdown]
# Model Predictions

# %%
reg_pred = regression.predict(x_test_norm)
reg_pred
# Out:
# array([1.04927477, 1.54143892, 2.24622242, ..., 1.88612132, 1.64142627,
#        1.66931348], shape=(6192,))

# %% [markdown]
# Calulate Residulas :-Residuals represent the model's errors. Positive residuals indicate underestimation, while negative residuals indicate overestimation.

# %%
residuals = y_test - reg_pred
residuals
# Out:
# 20046   -0.572275
# 3024    -1.083439
# 15663    2.753788
# 20484   -0.542757
# 9814     0.730247
#            ...
# 17505    0.450923
# 13512   -0.645169
# 10842    0.297879
# 16559   -0.447426
# 5786     0.428687
# Name: price, Length: 6192, dtype: float64

# %% [markdown]
# Visulalize Residulas

# %%
sns.displot(residuals,kind = 'kde')

# %% [markdown]
# As we can see due outliers the graph is very unusual trend in left side

# %% [markdown]
# Model Evalution we will get clear idea

# %% [markdown]
# Applying Evalution Metrics

# %%
from sklearn.metrics import  mean_squared_error , mean_absolute_error,r2_score
#  Assuming 'y_test' is the true target varible and 'reg_pred' is predicting values
mse = mean_squared_error(y_test,reg_pred)
mae = mean_absolute_error(y_test,reg_pred)
r2s = r2_score(y_test,reg_pred)

print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R-squared (R2): {r2s}")
# Out:
# Mean Squared Error (MSE): 0.6284038514263594
# Mean Absolute Error (MAE): 0.5919280736616849
# R-squared (R2): 0.5212307435899888

# %% [markdown]
# Calculating Adjusted R-Squared

# %%
# Assuming 'n_features' is the number of features in your model
n = len(y_test)  # Number of observations
r2 = r2_score(y_test, reg_pred)
n_features = x_test_norm.shape[1]
adjusted_r2 = 1 - ((1 - r2) * (n - 1) / (n - n_features - 1))  # formula of adjusted r sqr.

print(f"R-squared (R2): {r2:.2f}")
print(f"Adjusted R-squared: {adjusted_r2:.2f}")
# Out:
# R-squared (R2): 0.52
# Adjusted R-squared: 0.52

# %% [markdown]
# from this we can see that value of r2 and ajusted r2 is approx similar
# this happen due to bais value or due to outerliers

# %% [markdown]
# **Calculating RMSE**

# %%
# Assuming 'y_test' is the true target variable and 'reg_pred' is the predicted values
mse = mean_squared_error(y_test, reg_pred)
rmse = np.sqrt(mse)

print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
# Out:
# Mean Squared Error (MSE): 0.63
# Root Mean Squared Error (RMSE): 0.79

# %% [markdown]
# Saving This train data in pickle for future refrences

# %%
import pickle
pickle.dump(regression,open('regmodel.pkl','wb'))

# %% [markdown]
# Confirm the Model is saved

# %%
model = pickle.load(open('regmodel.pkl','rb'))

# %% [markdown]
# **Scaling New Data**

# %%
# Get the feature names the scaler was fitted on
feature_names_for_scaler = scaler.feature_names_in_

# Create a DataFrame from housing.data for easier column selection
housing_data_df = pd.DataFrame(data=housing.data, columns=housing.feature_names)

# Select only the features the scaler was trained on
input_data_for_scaler = housing_data_df[feature_names_for_scaler]

# Select the first row and transform it using the scaler
scaled_input = scaler.transform(input_data_for_scaler.iloc[0].values.reshape(1, -1))

model.predict(scaled_input)
# Out:
# c:\Users\v\Desktop\machine learning\california_house_prediction\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([4.08203695])
